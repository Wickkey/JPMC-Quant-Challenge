# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from typing import Optional
from scipy.stats import anderson, shapiro
import statsmodels.api as sm
from scipy.special import ive , iv # check if it's just modified bessel function of first kind
from scipy.optimize import fmin, fmin_powell, minimize
from matplotlib import cm
from matplotlib.ticker import LinearLocator

# %%
df = pd.read_csv('calibration_data_derivatives.csv')
df = df.drop(['Unnamed: 0'],axis=1)
T = df['T'].to_numpy()

# %%
df.head()
# Out:
#         T          0          1          2          3          4          5  \
# 0  0.0000  20.000000  20.000000  20.000000  20.000000  20.000000  20.000000
# 1  0.0004  20.009467  20.042233  20.054410  20.022644  20.019337  20.029027
# 2  0.0008  20.180659  20.034681  20.073286  20.071441  20.084694  20.072978
# 3  0.0012  20.250422  20.058778  20.108238  20.105163  20.124961  20.123804
# 4  0.0016  20.356734  20.099250  20.144123  20.196775  20.134417  20.205258
#
#            6          7          8  ...         90         91         92  \
# 0  20.000000  20.000000  20.000000  ...  20.000000  20.000000  20.000000
# 1  19.994295  20.022623  19.969734  ...  19.979903  20.033890  20.084984
# 2  20.044870  20.060890  20.013023  ...  19.945434  20.115835  20.151885
# 3  20.108782  20.123590  20.001301  ...  20.054304  20.108343  20.169604
# 4  20.159322  20.109303  20.087247  ...  20.091437  20.173392  20.220396
#
#           93         94         95         96         97         98         99
# 0  20.000000  20.000000  20.000000  20.000000  20.000000  20.000000  20.000000
# 1  20.030623  20.075743  20.071736  19.958307  20.073213  20.000348  20.030370
# 2  20.033409  20.139381  20.133000  20.002493  20.147919  20.031410  20.073345
# 3  20.058534  20.168256  20.200677  20.061395  20.216549  20.085283  20.083917
# 4  20.032751  20.258030  20.320258  20.100482  20.251627  20.066172  20.143806
#
# [5 rows x 101 columns]

# %%
class CIR:
    def __init__(self,a:float,b:float,sigma:float):
        self.a = a
        self.b = b 
        self.sigma = sigma 

    def post_init(self):
        if 2 * self.a * self.b > self.sigma ** 2:
            raise ValueError("For positive rate, 2ab has to be greater than or equal to c^2.")
        return None

    # generates data from the given configuration
    def generate_eulerCIR(self,S0, T, random_state:Optional[int] = None):
        a,b,sigma = self.a, self.b, self.sigma
        S = [S0]
        
        for i in range(len(T)-1):
            delT = T[i+1]-T[i]
            if random_state:
                np.random.seed(random_state+i)
                
            S_new = S[-1] + a*(b-S[-1])*delT + sigma*np.sqrt(max(S[-1],0)*delT)*np.random.normal()
            S.append(S_new)

        return np.array(S)

    def generate_PCeulerCIR(self, S0, T, random_state: Optional[int] = None):
        a,b,sigma = self.a, self.b, self.sigma
        S = [S0]

        for i in range(len(T)-1):
            delT = T[i+1]-T[i]
            if random_state:
                np.random.seed(random_state+i)
                
            S_star = S[-1] + a*(b-S[-1])*delT + sigma*np.sqrt(max(S[-1],0)*delT)*np.random.normal()
            S_new = S_star + (a*(S[-1]-S_star)*delT)/2

            S.append(S_new)

        return np.array(S)  

    def generate_milsteinCIR(self, S0, T, random_state:Optional[int]=None):
        a,b,sigma = self.a, self.b, self.sigma
        S = [S0]

        for i in range(len(T)-1):
            delT = T[i+1]-T[i]
            if random_state:
                np.random.seed(random_state+i)

            z = np.random.normal() 
            S_new = S[-1] + (a*b*delT) - (a*delT*S[-1]) + (sigma*np.sqrt(S[-1]*delT)*z) + ((sigma**2 * delT * (z**2 -1))/4)    
            S.append(S_new)

        return np.array(S)

# %% [markdown]
# ## Estimate Parameters

# %% [markdown]
# ### 1. OLS

# %%
class Solver:
    def OLS_statsmodel(self,X,y):
        # solve using stats model sm library implementation
        lr = sm.OLS(y, X).fit()
        print(lr.summary())
        
        thetahat = lr.params
        yhat = X@thetahat
        yhat = np.squeeze(yhat)
        error = y-yhat

        n = len(yhat)
        p = X.shape[1]

        varhat = error.T @ error / (n-p)
        sigmahat = np.sqrt(varhat)

        return [thetahat,sigmahat]    


    def OLS(self,X,y, estimate_metrics=False):
        ''' 
        Closed form solution for Linear Regression
        '''
        # Handtyped implementation
        thetahat = np.linalg.inv(X.T @ X) @ X.T @ y
        yhat = X@thetahat
        error = y-yhat
        
        n = len(yhat)
        p = X.shape[1]

        varhat = error.T @ error / (n-p)
        
        sigmahat = np.sqrt(varhat)

        if estimate_metrics:
            self.thetahat_cov = varhat*np.linalg.inv(X.T @ X)
            self.errorBias = np.mean(error)
            # anderson-darling test for checking normality condition for error terms
            result = anderson(error)
            stat, p = shapiro(error)
            alpha = 0.05 
            flag= True

            for i in range(len(result.critical_values)):
                sl, cv = result.significance_level[i], result.critical_values[i]
                if result.statistic < result.critical_values[i]:
                    pass
                else:
                    print('AD Test: Error does not look normal (reject H0)')
                    flag = False
                    break

            if flag: 
                print('AD Test: Error looks normal (fail to reject H0)')
                self.isWhite = True 
            else:
                self.isWhite = False

            if p > alpha:
                print('Shapiro Test: Sample looks Gaussian (fail to reject H0)')
            else:
                print('Shapiro Test: Sample does not look Gaussian (reject H0)')

        return [thetahat,sigmahat]

# %%
def estimateParams_euler(T, cir, estimate_metrics = False):
    delT = np.diff(T)
    y = np.diff(cir)/np.sqrt(cir[:-1])
    x1 = delT/np.sqrt(cir[:-1])
    x2 = -np.sqrt(cir[:-1])*delT

    X = np.array((x1,x2)).T
    solver = Solver()
    thetahat, sig = solver.OLS(X,y, estimate_metrics)


    abhat, ahat = thetahat
    bhat = abhat/ahat
    sigmahat = sig/np.sqrt(delT[0])

    if estimate_metrics: 
        print("Mean of Errors: ", solver.errorBias)
        print("Covariance matrix for parameter estimates: ", solver.thetahat_cov)
        # solver.OLS_statsmodel(X,y)
    return ahat,bhat, sigmahat

# %% [markdown]
# ### 2. MLE

# %%
def negloglik(x,T,cir):
    ''' 
    x is [a,b,sigma] 
    Evalues Negative Log Likelihood for parameters contained in x on cir. 
    '''
    dataF = cir[1:]
    dataL = cir[:-1]
    Nobs = len(cir)
    Timestep = (T[1]-T[0])
    a,b,sigma = x

    c = 2*a/((sigma**2) * (1-np.exp(-a*Timestep)))
    q = (2*a*b/(sigma**2)) - 1 
    u = c*dataL* np.exp(-a*Timestep)
    v = c*dataF
    z = 2* np.sqrt(u*v)  
    bf = ive(q,z)
    lnL = -(Nobs-1)*np.log(c) + np.sum(u+v - 0.5*q*np.log(v/u) - np.log(bf) - z)

    return lnL

# %%
def calibrate_dataOLS(df: pd.DataFrame,estimate_metrics = False):
    ''' 
    Calibrate the model parameters using OLS method
    '''
    ahatvec = []
    bhatvec = []
    sigmahatvec = []

    for i in tqdm(range(100)):
        cir = df[str(i)].to_numpy()
        guess = estimateParams_euler(T,cir, estimate_metrics)
        
        ahatvec.append(guess[0])
        bhatvec.append(guess[1])
        sigmahatvec.append(guess[2])  

        if estimate_metrics:
            print("")

    ahatmean = np.mean(ahatvec)
    bhatmean = np.mean(bhatvec)
    sigmahatvec = np.mean(sigmahatvec)

    return ahatmean, bhatmean, sigmahatvec

# %%
def calibrate_dataMLE(df: pd.DataFrame,method = "Nelder-Mead"):
    ''' 
    Calibrate the model parameters using MLE method. The initial guess is OLS estimate
    '''
    ahatvec = []
    bhatvec = []
    sigmahatvec = []
    nit = []

    for i in tqdm(range(100)):
        cir = df[str(i)].to_numpy()
        guess = estimateParams_euler(T,cir)
        xopt = minimize(fun=negloglik,args = (T,cir), x0=guess, method=method) 
        nit.append(xopt.nit)
        
        ahatvec.append(xopt.x[0])
        bhatvec.append(xopt.x[1])
        sigmahatvec.append(xopt.x[2])  

    ahatmean = np.mean(ahatvec)
    bhatmean = np.mean(bhatvec)
    sigmahatvec = np.mean(sigmahatvec)
    print("No of iter: ", np.mean(nit))

    return ahatmean, bhatmean, sigmahatvec

# %%
ols = calibrate_dataOLS(df)
ols
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 1644.20it/s]
# (0.9098468894490687, 135.09397038781802, 0.399912442590426)

# %%
a,b,sigma = calibrate_dataMLE(df)
# Out:
# 100%|██████████| 100/100 [00:21<00:00,  4.71it/s]

# %%
calibrate_dataMLE(df, method = 'bfgs')
# Out:
# 100%|██████████| 100/100 [00:33<00:00,  2.95it/s]
# (0.9098549658090235, 135.09396824764636, 0.39990949958243)

# %%
calibrate_dataMLE(df,method = 'L-BFGS-B')
# Out:
# 100%|██████████| 100/100 [00:06<00:00, 14.30it/s]
# (0.9069713800379191, 135.06920819671774, 0.3425973787638769)

# %% [markdown]
# ## Option Pricing

# %%
# estimated parameters from the given data through MLE 
a,b,sigma
# Out:
# (0.9100101993332262, 135.09418157986403, 0.39990734424709956)

# %%
calibrated_model = CIR(a,b,sigma)

# %%
# up and out putoption
def priceOption(S_b,K, cirmodel: CIR, strategy = "PC"):
    a,b,sigma = cirmodel.a, cirmodel.b, cirmodel.sigma
    r = 0.1 # discount rate
    tau = 4 # time to expiry
    S0 = 20 # starting price
    delT = 1/12 
    n = 100000 # realizations

    T = np.arange(0,tau+0.01,1/12)

    payoff_uo =[]
    payoff_ui = []
    payoff_p = []

##################################    
    if strategy.lower() == 'pc':
        for j in range(n):
            option_activity = S0<S_b # up and put option activity
            S = [S0] # spot price today

            for i in range(len(T)-1):
                S_star = S[-1] + a*(b-S[-1])*delT + sigma*np.sqrt(max(S[-1],0)*delT)*np.random.normal()
                S_new = S_star + (a*(S[-1]-S_star)*delT)/2
                S.append(S_new)

                if S_new > S_b:
                    option_activity = False 
                
            
            if option_activity: # up and out is active, up and in is inactive
                payoff_uo.append(max(K-S[-1],0))
                payoff_ui.append(0) 

            else:  # up and out is inactive, up and in is active
                payoff_uo.append(0)
                payoff_ui.append(max(K-S[-1],0))

            payoff_p.append(max(K-S[-1],0))     



####################################
    elif strategy.lower() == 'milstein':
        for j in range(n):
            option_activity = S0<S_b # up and put option activity
            S = [S0] # spot price today

            for i in range(len(T)-1):
                z = np.random.normal() 
                S_new = S[-1] + (a*b*delT) - (a*delT*S[-1]) + (sigma*np.sqrt(S[-1]*delT)*z) + ((sigma**2 * delT * (z**2 -1))/4)    
                S.append(S_new)

                if S_new > S_b:
                    option_activity = False 
                
            
            if option_activity: # up and out is active, up and in is inactive
                payoff_uo.append(max(K-S[-1],0))
                payoff_ui.append(0) 

            else:  # up and out is inactive, up and in is active
                payoff_uo.append(0)
                payoff_ui.append(max(K-S[-1],0))

            payoff_p.append(max(K-S[-1],0)) 


#####################################
    else:
        if strategy.lower() == 'euler':
            pass 
        else:
            print("Discretization Strategy not found. Using Euler Maurayana method")

        for j in range(n):
            option_activity = S0<S_b # up and put option activity
            S = [S0] # spot price today

            for i in range(len(T)-1):
                S_new = S[-1] + a*(b-S[-1])*delT + sigma*np.sqrt(max(S[-1],0)*delT)*np.random.normal()
                S.append(S_new)

                if S_new > S_b:
                    option_activity = False 
                
            
            if option_activity: # up and out is active, up and in is inactive
                payoff_uo.append(max(K-S[-1],0))
                payoff_ui.append(0) 

            else:  # up and out is inactive, up and in is active
                payoff_uo.append(0)
                payoff_ui.append(max(K-S[-1],0))

            payoff_p.append(max(K-S[-1],0)) 
        

########################## 
    payoff_uo = np.array(payoff_uo)
    payoff_ui = np.array(payoff_ui)
    payoff_p = np.array(payoff_p)

    uo,ui,p = [np.mean(payoff_uo),np.mean(payoff_ui),np.mean(payoff_p)]
    
    option_price = [uo*np.exp(-r*tau),ui*np.exp(-r*tau),p*np.exp(-r*tau) ]
        
    return option_price

# %%
S_b = [140,140,137,139,150,145,132]
K = [145,150,137,139,200,145,132]

# %%
df = pd.DataFrame()

# %%
uo = []
ui = []
p = []
for i in tqdm(range(len(K))):
    price = priceOption(S_b[i],K[i],calibrated_model,strategy="pc")
    uo.append(price[0])
    ui.append(price[1])
    p.append(price[2])
# Out:
# 100%|██████████| 7/7 [02:44<00:00, 23.54s/it]

# %%
df["S_b"] = S_b
df["K"] = K 
df["Up and Out Put"] = uo 
df["Up and In Put"] = ui 
df['Put'] = p

# %%
# note the parity
df
# Out:
#    S_b    K  Up and Out Put  Up and In Put        Put
# 0  140  145        8.606491       0.064784   8.671275
# 1  140  150       11.892999       0.129109  12.022108
# 2  137  137        3.325484       0.065847   3.391331
# 3  139  139        4.654781       0.022847   4.677628
# 4  150  200       45.547866       0.000000  45.547866
# 5  145  145        8.673678       0.000178   8.673855
# 6  132  132        0.699778       0.172378   0.872155

# %% [markdown]
# ## Ranking Discretization Methods

# %%
def exp_stockprice(cirmodel:CIR, S0, t):
    a,b,sigma = cirmodel.a, cirmodel.b, cirmodel.sigma 

    return S0*np.exp(-a*t) + b*(1-np.exp(-a*t))

# %%
# expected stock price value at time t using probability
exp_stockprice(calibrated_model,50,4)
# Out:
# 132.86035099173992

# %%
time = np.arange(0,4.01,1/12)

# %%
# expected stock price value at time t using Monte Carlo Simulation
n=10000

sp_euler = []
sp_pc = []
sp_mil = []
for i in range(n):
    sp_euler.append(calibrated_model.generate_eulerCIR(50,time)[-1])
    sp_pc.append(calibrated_model.generate_PCeulerCIR(50,time)[-1])
    sp_mil.append(calibrated_model.generate_milsteinCIR(50,time)[-1])

# %%
print('Actual: ',exp_stockprice(calibrated_model,50,4))
print('Euler: ', np.mean(sp_euler))
print('PC: ', np.mean(sp_pc))
print('Milstein: ', np.mean(sp_mil))
# Out:
# Actual:  132.86035099173992
# Euler:  133.19208385411977
# PC:  132.80572110639673
# Milstein:  133.15432029695475

# %% [markdown]
# PC is the best discretization method among the three discussed

# %% [markdown]
# ## Appendix

# %% [markdown]
# #### 1. OLS

# %%
calibrate_dataOLS(df, estimate_metrics=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]c:\Users\vigne\anaconda3\lib\site-packages\scipy\stats\morestats.py:1760: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
#  32%|███▏      | 32/100 [00:00<00:00, 317.01it/s]
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -1.5359973561319768e-06
# Covariance matrix for parameter estimates:  [[2.65193527e+01 2.77841645e-01]
#  [2.77841645e-01 3.47790750e-03]]
#
# AD Test: Error does not look normal (reject H0)
# Shapiro Test: Sample does not look Gaussian (reject H0)
# Mean of Errors:  -1.8721418762017657e-06
# Covariance matrix for parameter estimates:  [[2.74432003e+01 2.90586286e-01]
#  [2.90586286e-01 3.65448495e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  9.386730496298689e-07
# Covariance matrix for parameter estimates:  [[2.72544256e+01 2.90767829e-01]
#  [2.90767829e-01 3.66474907e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  8.233685584149347e-07
# Covariance matrix for parameter estimates:  [[2.68906181e+01 2.82799022e-01]
#  [2.82799022e-01 3.52494068e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -2.5491064640896064e-06
# Covariance matrix for parameter estimates:  [[2.50856078e+01 2.61108939e-01]
#  [2.61108939e-01 3.26494910e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  1.987837479186206e-06
# Covariance matrix for parameter estimates:  [[2.91272023e+01 3.09112470e-01]
#  [3.09112470e-01 3.84089773e-03]]
#
# AD Test: Error does not look normal (reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -2.5833156367268964e-06
# Covariance matrix for parameter estimates:  [[2.78343089e+01 2.93620586e-01]
#  [2.93620586e-01 3.65794682e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -7.071577739172601e-07
# Covariance matrix for parameter estimates:  [[2.64063863e+01 2.80817864e-01]
#  [2.80817864e-01 3.55615709e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  2.188792337455621e-06
# Covariance matrix for parameter estimates:  [[2.50866195e+01 2.54453623e-01]
#  [2.54453623e-01 3.11857339e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  9.262384265185634e-07
# Covariance matrix for parameter estimates:  [[2.81767623e+01 2.91294080e-01]
#  [2.91294080e-01 3.57152341e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  2.1781467802691518e-07
# Covariance matrix for parameter estimates:  [[2.88827442e+01 3.08525875e-01]
#  [3.08525875e-01 3.86574979e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  2.581719651593784e-06
# Covariance matrix for parameter estimates:  [[2.67874511e+01 2.80217062e-01]
#  [2.80217062e-01 3.49291569e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -6.264651862405676e-07
# Covariance matrix for parameter estimates:  [[2.63129390e+01 2.77623474e-01]
#  [2.77623474e-01 3.48270369e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -5.189305254948576e-07
# Covariance matrix for parameter estimates:  [[2.71796422e+01 2.80533100e-01]
#  [2.80533100e-01 3.43661380e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  3.6319825323807344e-06
# Covariance matrix for parameter estimates:  [[2.78461653e+01 2.88196716e-01]
#  [2.88196716e-01 3.53826149e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -1.4463099623399262e-07
# Covariance matrix for parameter estimates:  [[2.74657059e+01 2.86118337e-01]
#  [2.86118337e-01 3.53112161e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  1.5653218433590956e-06
# Covariance matrix for parameter estimates:  [[2.83505839e+01 2.95345312e-01]
#  [2.95345312e-01 3.65248119e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -2.8874475903922677e-07
# Covariance matrix for parameter estimates:  [[2.91666571e+01 3.02781361e-01]
#  [3.02781361e-01 3.68865569e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  3.443563537762384e-06
# Covariance matrix for parameter estimates:  [[2.59578376e+01 2.71731777e-01]
#  [2.71731777e-01 3.38475219e-03]]
#
# AD Test: Error does not look normal (reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  2.507550715145548e-06
# Covariance matrix for parameter estimates:  [[2.54243711e+01 2.64382168e-01]
#  [2.64382168e-01 3.30445594e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  3.783494575704075e-06
# Covariance matrix for parameter estimates:  [[2.70238485e+01 2.83686344e-01]
#  [2.83686344e-01 3.52585470e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  2.686821301348123e-06
# Covariance matrix for parameter estimates:  [[2.77921992e+01 2.88493004e-01]
#  [2.88493004e-01 3.54748562e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -1.3094365596216195e-06
# Covariance matrix for parameter estimates:  [[2.65615988e+01 2.79265199e-01]
#  [2.79265199e-01 3.50228594e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -1.6457824086861063e-06
# Covariance matrix for parameter estimates:  [[2.85303097e+01 3.00657654e-01]
#  [3.00657654e-01 3.73919311e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  5.218178697716964e-06
# Covariance matrix for parameter estimates:  [[2.39687018e+01 2.45831251e-01]
#  [2.45831251e-01 3.04619948e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -8.584342869806351e-07
# Covariance matrix for parameter estimates:  [[2.66671131e+01 2.75352896e-01]
#  [2.75352896e-01 3.40393782e-03]]
#
# AD Test: Error does not look normal (reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  3.160886089513515e-08
# Covariance matrix for parameter estimates:  [[2.67050924e+01 2.87214322e-01]
#  [2.87214322e-01 3.66480814e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  6.643066446152912e-07
# Covariance matrix for parameter estimates:  [[2.70738758e+01 2.85447362e-01]
#  [2.85447362e-01 3.57483101e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  2.565573504474916e-06
# Covariance matrix for parameter estimates:  [[2.60187944e+01 2.64131358e-01]
#  [2.64131358e-01 3.22475792e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  2.443554311166177e-06
# Covariance matrix for parameter estimates:  [[2.60921018e+01 2.74762770e-01]
#  [2.74762770e-01 3.47212127e-03]]
#
# AD Test: Error does not look normal (reject H0)
# Shapiro Test: Sample does not look Gaussian (reject H0)
# Mean of Errors:  4.067073654406234e-06
# Covariance matrix for parameter estimates:  [[2.78183373e+01 2.93849962e-01]
#  [2.93849962e-01 3.66950062e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  1.4344071407370417e-06
# Covariance matrix for parameter estimates:  [[2.52746593e+01 2.56420319e-01]
#  [2.56420319e-01 3.13925363e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -4.274513496166729e-07
# Covariance matrix for parameter estimates:  [[2.81630354e+01 3.04440863e-01]
#  [3.04440863e-01 3.88121173e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -3.288191682038161e-06
# Covariance matrix for parameter estimates:  [[2.81455212e+01 2.92590589e-01]
#  [2.92590589e-01 3.61803621e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -2.7055452157159643e-06
# Covariance matrix for parameter estimates:  [[2.93439559e+01 3.11261555e-01]
#  [3.11261555e-01 3.88045158e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  8.624999934808844e-07
# Covariance matrix for parameter estimates:  [[2.60747447e+01 2.74060361e-01]
#  [2.74060361e-01 3.45207938e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  3.3186831739735666e-07
# Covariance matrix for parameter estimates:  [[2.77758272e+01 2.91029658e-01]
#  [2.91029658e-01 3.61294021e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  3.703171258347935e-08
# Covariance matrix for parameter estimates:  [[2.53066084e+01 2.65649237e-01]
#  [2.65649237e-01 3.34908902e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  1.7879101021942626e-06
# Covariance matrix for parameter estimates:  [[2.65564274e+01 2.81205819e-01]
#  [2.81205819e-01 3.53787527e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  2.0518933229137774e-06
# Covariance matrix for parameter estimates:  [[2.66298824e+01 2.70287200e-01]
#  [2.70287200e-01 3.28326507e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  7.885295538486716e-07
# Covariance matrix for parameter estimates:  [[2.54483214e+01 2.68962601e-01]
#  [2.68962601e-01 3.39686500e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -2.9981332007305497e-06
# Covariance matrix for parameter estimates:  [[2.62089492e+01 2.63251462e-01]
#  [2.63251462e-01 3.17088778e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  2.2819440408008453e-06
# Covariance matrix for parameter estimates:  [[2.57257479e+01 2.71778103e-01]
#  [2.71778103e-01 3.44392482e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -2.3304448747651059e-07
# Covariance matrix for parameter estimates:  [[2.64501163e+01 2.73118153e-01]
#  [2.73118153e-01 3.35793571e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  2.497699100034632e-06
# Covariance matrix for parameter estimates:  [[2.50573344e+01 2.58133752e-01]
#  [2.58133752e-01 3.19785430e-03]]
#
# AD Test: Error does not look normal (reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -1.3160486885601052e-06
# Covariance matrix for parameter estimates:  [[2.81024613e+01 2.93012936e-01]
#  [2.93012936e-01 3.61419286e-03]]
#
# AD Test: Error does not look normal (reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -1.9782592746332156e-06
# Covariance matrix for parameter estimates:  [[2.79288132e+01 2.95095034e-01]
#  [2.95095034e-01 3.68160468e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -4.2431529671154067e-07
# Covariance matrix for parameter estimates:  [[2.80339789e+01 2.91126126e-01]
#  [2.91126126e-01 3.56584519e-03]]
#
# AD Test: Error does not look normal (reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  1.3324327758762854e-06
# Covariance matrix for parameter estimates:  [[2.70159636e+01 2.80087928e-01]
#  [2.80087928e-01 3.45513419e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -2.1389191764917448e-07
# Covariance matrix for parameter estimates:  [[2.70743142e+01 2.88383002e-01]
#  [2.88383002e-01 3.64233835e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  2.6154916957902634e-06
# Covariance matrix for parameter estimates:  [[2.69640719e+01 2.78435870e-01]
#  [2.78435870e-01 3.41829895e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  4.18355037625414e-06
# Covariance matrix for parameter estimates:  [[2.57746996e+01 2.69237813e-01]
#  [2.69237813e-01 3.38168150e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  1.346021372477669e-06
# Covariance matrix for parameter estimates:  [[2.77125662e+01 2.94439581e-01]
#  [2.94439581e-01 3.69039064e-03]]
#
# AD Test: Error does not look normal (reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  1.0565262729266962e-06
# Covariance matrix for parameter estimates:  [[2.67741174e+01 2.89781864e-01]
#  [2.89781864e-01 3.71179233e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -4.98978151994001e-06
# Covariance matrix for parameter estimates:  [[2.72701480e+01 2.83825968e-01]
#  [2.83825968e-01 3.52343904e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  4.884528048113964e-06
# Covariance matrix for parameter estimates:  [[2.52763005e+01 2.54102808e-01]
#  [2.54102808e-01 3.09267375e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  2.5317937437689512e-06
# Covariance matrix for parameter estimates:  [[2.49673699e+01 2.62560389e-01]
#  [2.62560389e-01 3.32096760e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -1.949552321958924e-06
# Covariance matrix for parameter estimates:  [[2.70261989e+01 2.87338541e-01]
#  [2.87338541e-01 3.62921966e-03]]
# 100%|██████████| 100/100 [00:00<00:00, 347.57it/s]
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -4.777094987892468e-07
# Covariance matrix for parameter estimates:  [[2.79750122e+01 2.95307303e-01]
#  [2.95307303e-01 3.68788053e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  1.6654138362120178e-06
# Covariance matrix for parameter estimates:  [[2.75879940e+01 2.80908977e-01]
#  [2.80908977e-01 3.40894052e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  5.609315272417722e-07
# Covariance matrix for parameter estimates:  [[2.69431726e+01 2.83226408e-01]
#  [2.83226408e-01 3.54472656e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  1.8054716502485332e-06
# Covariance matrix for parameter estimates:  [[2.70538138e+01 2.84260948e-01]
#  [2.84260948e-01 3.54993557e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  5.048269389499728e-07
# Covariance matrix for parameter estimates:  [[2.73318999e+01 2.85467642e-01]
#  [2.85467642e-01 3.52193791e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  3.2934873330975583e-06
# Covariance matrix for parameter estimates:  [[2.74543298e+01 2.79252144e-01]
#  [2.79252144e-01 3.39179122e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  3.982687706936865e-06
# Covariance matrix for parameter estimates:  [[2.65455719e+01 2.85649337e-01]
#  [2.85649337e-01 3.62928671e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -3.8208957352466945e-06
# Covariance matrix for parameter estimates:  [[2.70602587e+01 2.89302496e-01]
#  [2.89302496e-01 3.65336833e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  1.6511869805965373e-06
# Covariance matrix for parameter estimates:  [[2.55826075e+01 2.69146636e-01]
#  [2.69146636e-01 3.38995553e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  2.36963113295341e-06
# Covariance matrix for parameter estimates:  [[2.65609011e+01 2.72704772e-01]
#  [2.72704772e-01 3.34819508e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  1.992786052332972e-06
# Covariance matrix for parameter estimates:  [[2.62047526e+01 2.74871579e-01]
#  [2.74871579e-01 3.43249056e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -1.8455742155437781e-06
# Covariance matrix for parameter estimates:  [[2.59579136e+01 2.66523414e-01]
#  [2.66523414e-01 3.28451748e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -3.0171586088032446e-06
# Covariance matrix for parameter estimates:  [[2.80045311e+01 2.94565520e-01]
#  [2.94565520e-01 3.66128664e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -1.829651733441116e-06
# Covariance matrix for parameter estimates:  [[2.76193027e+01 2.91518947e-01]
#  [2.91518947e-01 3.65205021e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -1.2058963792255721e-06
# Covariance matrix for parameter estimates:  [[2.73174926e+01 2.82646579e-01]
#  [2.82646579e-01 3.47876983e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  1.568287077106769e-06
# Covariance matrix for parameter estimates:  [[2.76807427e+01 2.86133111e-01]
#  [2.86133111e-01 3.50792483e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -2.1723390224171064e-06
# Covariance matrix for parameter estimates:  [[2.59587811e+01 2.71432429e-01]
#  [2.71432429e-01 3.39775974e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -7.778885633854744e-07
# Covariance matrix for parameter estimates:  [[2.64049913e+01 2.70729681e-01]
#  [2.70729681e-01 3.30646154e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  9.336578113991543e-07
# Covariance matrix for parameter estimates:  [[2.55077093e+01 2.73902027e-01]
#  [2.73902027e-01 3.51107589e-03]]
#
# AD Test: Error does not look normal (reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -3.961591753172963e-06
# Covariance matrix for parameter estimates:  [[2.73101627e+01 2.82789925e-01]
#  [2.82789925e-01 3.47866687e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -1.9649965621067395e-06
# Covariance matrix for parameter estimates:  [[2.76057327e+01 2.96700840e-01]
#  [2.96700840e-01 3.75665049e-03]]
#
# AD Test: Error does not look normal (reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -9.274237788307976e-07
# Covariance matrix for parameter estimates:  [[2.69801654e+01 2.82051231e-01]
#  [2.82051231e-01 3.50924627e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  5.534148244595221e-08
# Covariance matrix for parameter estimates:  [[2.45658470e+01 2.54382504e-01]
#  [2.54382504e-01 3.17123648e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -1.5251981144177958e-06
# Covariance matrix for parameter estimates:  [[2.66099662e+01 2.77728394e-01]
#  [2.77728394e-01 3.44285282e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  5.984790187980626e-07
# Covariance matrix for parameter estimates:  [[2.64132745e+01 2.74612672e-01]
#  [2.74612672e-01 3.40497826e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -4.269268419214302e-06
# Covariance matrix for parameter estimates:  [[2.60599222e+01 2.68326519e-01]
#  [2.68326519e-01 3.29596711e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -6.991928486360455e-07
# Covariance matrix for parameter estimates:  [[2.66571394e+01 2.89487496e-01]
#  [2.89487496e-01 3.71334970e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -2.978937362662954e-06
# Covariance matrix for parameter estimates:  [[2.82113414e+01 3.01318484e-01]
#  [3.01318484e-01 3.79311366e-03]]
#
# AD Test: Error does not look normal (reject H0)
# Shapiro Test: Sample does not look Gaussian (reject H0)
# Mean of Errors:  3.6855661144323993e-06
# Covariance matrix for parameter estimates:  [[2.57331297e+01 2.66764289e-01]
#  [2.66764289e-01 3.31002155e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  9.618728674736538e-07
# Covariance matrix for parameter estimates:  [[2.5804861e+01 2.7106905e-01]
#  [2.7106905e-01 3.4076976e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -4.651337482561546e-07
# Covariance matrix for parameter estimates:  [[2.76417925e+01 2.88567350e-01]
#  [2.88567350e-01 3.56954856e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  4.437524001852961e-06
# Covariance matrix for parameter estimates:  [[2.64091203e+01 2.67463377e-01]
#  [2.67463377e-01 3.26007291e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  6.981731698116416e-07
# Covariance matrix for parameter estimates:  [[2.66265897e+01 2.85972351e-01]
#  [2.85972351e-01 3.64397978e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  4.065189021584956e-06
# Covariance matrix for parameter estimates:  [[2.67835163e+01 2.84756312e-01]
#  [2.84756312e-01 3.59110888e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  8.437450684631398e-07
# Covariance matrix for parameter estimates:  [[2.55887953e+01 2.61336921e-01]
#  [2.61336921e-01 3.21169909e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  2.9901939662092753e-07
# Covariance matrix for parameter estimates:  [[2.63322417e+01 2.76611782e-01]
#  [2.76611782e-01 3.46427388e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  3.0207090546841547e-07
# Covariance matrix for parameter estimates:  [[2.74148982e+01 2.86111306e-01]
#  [2.86111306e-01 3.54088077e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -3.849275372514022e-06
# Covariance matrix for parameter estimates:  [[2.64153244e+01 2.76705639e-01]
#  [2.76705639e-01 3.45599074e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  2.7898621672082874e-06
# Covariance matrix for parameter estimates:  [[2.63652675e+01 2.77450431e-01]
#  [2.77450431e-01 3.49853157e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -1.961530247166801e-07
# Covariance matrix for parameter estimates:  [[2.65198816e+01 2.80018321e-01]
#  [2.80018321e-01 3.52959765e-03]]
#
# AD Test: Error looks normal (fail to reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -1.8696609897182167e-06
# Covariance matrix for parameter estimates:  [[2.63403024e+01 2.75426657e-01]
#  [2.75426657e-01 3.44047878e-03]]
#
# AD Test: Error does not look normal (reject H0)
# Shapiro Test: Sample looks Gaussian (fail to reject H0)
# Mean of Errors:  -6.62427983151913e-08
# Covariance matrix for parameter estimates:  [[2.72077678e+01 2.86713104e-01]
#  [2.86713104e-01 3.59835889e-03]]
# (0.9098468894490687, 135.09397038781802, 0.399912442590426)

# %%
for i in tqdm(range(100)):
    Y = (df[str(i)].diff())/np.sqrt(df[str(i)])
    x1 = df['T'].diff()/np.sqrt(df[str(i)])
    x2 = -np.sqrt(df[str(i)])*(df['T'].diff())

    Y.drop(0,inplace=True)
    x1.drop(0,inplace=True)
    x2.drop(0,inplace=True)

    X = np.array((x1,x2)).T
    lr = sm.OLS(Y, X).fit()
    print(lr.summary())
# Out:
#  25%|██▌       | 25/100 [00:00<00:00, 127.86it/s]
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      0   R-squared (uncentered):                   0.094
# Model:                            OLS   Adj. R-squared (uncentered):              0.094
# Method:                 Least Squares   F-statistic:                              387.8
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   5.37e-161
# Time:                        22:50:24   Log-Likelihood:                          25511.
# No. Observations:                7499   AIC:                                 -5.102e+04
# Df Residuals:                    7497   BIC:                                 -5.100e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           117.6729      5.156     22.823      0.000     107.566     127.780
# x2             0.8526      0.059     14.443      0.000       0.737       0.968
# ==============================================================================
# Omnibus:                        0.564   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.754   Jarque-Bera (JB):                0.524
# Skew:                          -0.013   Prob(JB):                        0.769
# Kurtosis:                       3.031   Cond. No.                         217.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      1   R-squared (uncentered):                   0.093
# Model:                            OLS   Adj. R-squared (uncentered):              0.093
# Method:                 Least Squares   F-statistic:                              384.4
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   1.14e-159
# Time:                        22:50:24   Log-Likelihood:                          25482.
# No. Observations:                7499   AIC:                                 -5.096e+04
# Df Residuals:                    7497   BIC:                                 -5.095e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           118.2755      5.245     22.550      0.000     107.994     128.557
# x2             0.8644      0.061     14.285      0.000       0.746       0.983
# ==============================================================================
# Omnibus:                        5.553   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.062   Jarque-Bera (JB):                5.512
# Skew:                           0.064   Prob(JB):                       0.0635
# Kurtosis:                       3.033   Cond. No.                         218.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      2   R-squared (uncentered):                   0.095
# Model:                            OLS   Adj. R-squared (uncentered):              0.095
# Method:                 Least Squares   F-statistic:                              395.5
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   5.19e-164
# Time:                        22:50:24   Log-Likelihood:                          25608.
# No. Observations:                7499   AIC:                                 -5.121e+04
# Df Residuals:                    7497   BIC:                                 -5.120e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           125.0706      5.228     23.925      0.000     114.823     135.318
# x2             0.9834      0.061     16.228      0.000       0.865       1.102
# ==============================================================================
# Omnibus:                        0.383   Durbin-Watson:                   1.964
# Prob(Omnibus):                  0.826   Jarque-Bera (JB):                0.343
# Skew:                           0.000   Prob(JB):                        0.842
# Kurtosis:                       3.033   Cond. No.                         220.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      3   R-squared (uncentered):                   0.099
# Model:                            OLS   Adj. R-squared (uncentered):              0.098
# Method:                 Least Squares   F-statistic:                              409.9
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   1.20e-169
# Time:                        22:50:24   Log-Likelihood:                          25633.
# No. Observations:                7499   AIC:                                 -5.126e+04
# Df Residuals:                    7497   BIC:                                 -5.125e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           123.8620      5.192     23.855      0.000     113.684     134.041
# x2             0.9308      0.059     15.661      0.000       0.814       1.047
# ==============================================================================
# Omnibus:                        1.196   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.550   Jarque-Bera (JB):                1.192
# Skew:                          -0.031   Prob(JB):                        0.551
# Kurtosis:                       3.000   Cond. No.                         221.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      4   R-squared (uncentered):                   0.096
# Model:                            OLS   Adj. R-squared (uncentered):              0.095
# Method:                 Least Squares   F-statistic:                              396.2
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   2.72e-164
# Time:                        22:50:24   Log-Likelihood:                          25620.
# No. Observations:                7499   AIC:                                 -5.124e+04
# Df Residuals:                    7497   BIC:                                 -5.122e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           116.4131      5.014     23.215      0.000     106.583     126.243
# x2             0.8391      0.057     14.672      0.000       0.727       0.951
# ==============================================================================
# Omnibus:                        9.564   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               11.066
# Skew:                           0.004   Prob(JB):                      0.00395
# Kurtosis:                       3.188   Cond. No.                         214.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      5   R-squared (uncentered):                   0.100
# Model:                            OLS   Adj. R-squared (uncentered):              0.100
# Method:                 Least Squares   F-statistic:                              418.8
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   3.87e-173
# Time:                        22:50:24   Log-Likelihood:                          25602.
# No. Observations:                7499   AIC:                                 -5.120e+04
# Df Residuals:                    7497   BIC:                                 -5.119e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           133.9258      5.405     24.780      0.000     123.331     144.520
# x2             1.0671      0.062     17.198      0.000       0.945       1.189
# ==============================================================================
# Omnibus:                        0.410   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.815   Jarque-Bera (JB):                0.427
# Skew:                           0.017   Prob(JB):                        0.808
# Kurtosis:                       2.986   Cond. No.                         228.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      6   R-squared (uncentered):                   0.098
# Model:                            OLS   Adj. R-squared (uncentered):              0.098
# Method:                 Least Squares   F-statistic:                              407.6
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   8.95e-169
# Time:                        22:50:24   Log-Likelihood:                          25579.
# No. Observations:                7499   AIC:                                 -5.115e+04
# Df Residuals:                    7497   BIC:                                 -5.114e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           125.1020      5.283     23.681      0.000     114.746     135.458
# x2             0.9417      0.061     15.555      0.000       0.823       1.060
# ==============================================================================
# Omnibus:                        1.134   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.567   Jarque-Bera (JB):                1.104
# Skew:                          -0.005   Prob(JB):                        0.576
# Kurtosis:                       3.059   Cond. No.                         223.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      7   R-squared (uncentered):                   0.092
# Model:                            OLS   Adj. R-squared (uncentered):              0.092
# Method:                 Least Squares   F-statistic:                              381.9
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   1.17e-158
# Time:                        22:50:24   Log-Likelihood:                          25549.
# No. Observations:                7499   AIC:                                 -5.109e+04
# Df Residuals:                    7497   BIC:                                 -5.108e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           116.5505      5.145     22.654      0.000     106.465     126.636
# x2             0.8614      0.060     14.431      0.000       0.744       0.978
# ==============================================================================
# Omnibus:                        1.007   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.604   Jarque-Bera (JB):                1.039
# Skew:                           0.025   Prob(JB):                        0.595
# Kurtosis:                       2.972   Cond. No.                         216.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      8   R-squared (uncentered):                   0.099
# Model:                            OLS   Adj. R-squared (uncentered):              0.099
# Method:                 Least Squares   F-statistic:                              412.6
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   1.04e-170
# Time:                        22:50:24   Log-Likelihood:                          25589.
# No. Observations:                7499   AIC:                                 -5.117e+04
# Df Residuals:                    7497   BIC:                                 -5.116e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           116.6687      5.014     23.266      0.000     106.839     126.498
# x2             0.7925      0.056     14.179      0.000       0.683       0.902
# ==============================================================================
# Omnibus:                        0.354   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.838   Jarque-Bera (JB):                0.317
# Skew:                          -0.007   Prob(JB):                        0.854
# Kurtosis:                       3.029   Cond. No.                         216.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      9   R-squared (uncentered):                   0.099
# Model:                            OLS   Adj. R-squared (uncentered):              0.099
# Method:                 Least Squares   F-statistic:                              412.8
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   8.20e-171
# Time:                        22:50:24   Log-Likelihood:                          25507.
# No. Observations:                7499   AIC:                                 -5.101e+04
# Df Residuals:                    7497   BIC:                                 -5.100e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           128.3682      5.315     24.151      0.000     117.949     138.788
# x2             0.9584      0.060     16.020      0.000       0.841       1.076
# ==============================================================================
# Omnibus:                        1.381   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.501   Jarque-Bera (JB):                1.386
# Skew:                           0.008   Prob(JB):                        0.500
# Kurtosis:                       2.935   Cond. No.                         225.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     10   R-squared (uncentered):                   0.097
# Model:                            OLS   Adj. R-squared (uncentered):              0.097
# Method:                 Least Squares   F-statistic:                              403.5
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   3.56e-167
# Time:                        22:50:24   Log-Likelihood:                          25563.
# No. Observations:                7499   AIC:                                 -5.112e+04
# Df Residuals:                    7497   BIC:                                 -5.111e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           130.3876      5.382     24.228      0.000     119.838     140.937
# x2             1.0383      0.062     16.681      0.000       0.916       1.160
# ==============================================================================
# Omnibus:                        0.457   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.796   Jarque-Bera (JB):                0.486
# Skew:                           0.016   Prob(JB):                        0.784
# Kurtosis:                       2.977   Cond. No.                         225.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     11   R-squared (uncentered):                   0.095
# Model:                            OLS   Adj. R-squared (uncentered):              0.095
# Method:                 Least Squares   F-statistic:                              395.3
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   6.33e-164
# Time:                        22:50:24   Log-Likelihood:                          25541.
# No. Observations:                7499   AIC:                                 -5.108e+04
# Df Residuals:                    7497   BIC:                                 -5.106e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           121.8177      5.182     23.507      0.000     111.659     131.976
# x2             0.9085      0.059     15.357      0.000       0.793       1.024
# ==============================================================================
# Omnibus:                        0.065   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.968   Jarque-Bera (JB):                0.087
# Skew:                           0.001   Prob(JB):                        0.958
# Kurtosis:                       2.983   Cond. No.                         219.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     12   R-squared (uncentered):                   0.096
# Model:                            OLS   Adj. R-squared (uncentered):              0.096
# Method:                 Least Squares   F-statistic:                              400.3
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   6.40e-166
# Time:                        22:50:24   Log-Likelihood:                          25627.
# No. Observations:                7499   AIC:                                 -5.125e+04
# Df Residuals:                    7497   BIC:                                 -5.124e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           120.2395      5.136     23.411      0.000     110.171     130.308
# x2             0.8944      0.059     15.142      0.000       0.779       1.010
# ==============================================================================
# Omnibus:                        0.966   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.617   Jarque-Bera (JB):                0.924
# Skew:                          -0.014   Prob(JB):                        0.630
# Kurtosis:                       3.047   Cond. No.                         218.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     13   R-squared (uncentered):                   0.102
# Model:                            OLS   Adj. R-squared (uncentered):              0.102
# Method:                 Least Squares   F-statistic:                              427.2
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   2.01e-176
# Time:                        22:50:24   Log-Likelihood:                          25630.
# No. Observations:                7499   AIC:                                 -5.126e+04
# Df Residuals:                    7497   BIC:                                 -5.124e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           128.0246      5.220     24.524      0.000     117.791     138.258
# x2             0.9512      0.059     16.209      0.000       0.836       1.066
# ==============================================================================
# Omnibus:                        0.944   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.624   Jarque-Bera (JB):                0.974
# Skew:                           0.010   Prob(JB):                        0.614
# Kurtosis:                       2.948   Cond. No.                         224.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     14   R-squared (uncentered):                   0.100
# Model:                            OLS   Adj. R-squared (uncentered):              0.100
# Method:                 Least Squares   F-statistic:                              415.5
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   7.19e-172
# Time:                        22:50:24   Log-Likelihood:                          25542.
# No. Observations:                7499   AIC:                                 -5.108e+04
# Df Residuals:                    7497   BIC:                                 -5.107e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           127.2376      5.284     24.080      0.000     116.880     137.596
# x2             0.9430      0.060     15.837      0.000       0.826       1.060
# ==============================================================================
# Omnibus:                        1.502   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.472   Jarque-Bera (JB):                1.537
# Skew:                          -0.030   Prob(JB):                        0.464
# Kurtosis:                       2.963   Cond. No.                         224.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     15   R-squared (uncentered):                   0.100
# Model:                            OLS   Adj. R-squared (uncentered):              0.100
# Method:                 Least Squares   F-statistic:                              415.5
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   7.55e-172
# Time:                        22:50:24   Log-Likelihood:                          25600.
# No. Observations:                7499   AIC:                                 -5.120e+04
# Df Residuals:                    7497   BIC:                                 -5.118e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           128.6966      5.248     24.524      0.000     118.409     138.984
# x2             0.9849      0.059     16.558      0.000       0.868       1.102
# ==============================================================================
# Omnibus:                        0.783   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.676   Jarque-Bera (JB):                0.742
# Skew:                           0.005   Prob(JB):                        0.690
# Kurtosis:                       3.048   Cond. No.                         224.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     16   R-squared (uncentered):                   0.095
# Model:                            OLS   Adj. R-squared (uncentered):              0.095
# Method:                 Least Squares   F-statistic:                              395.3
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   6.18e-164
# Time:                        22:50:24   Log-Likelihood:                          25433.
# No. Observations:                7499   AIC:                                 -5.086e+04
# Df Residuals:                    7497   BIC:                                 -5.085e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           125.1631      5.332     23.476      0.000     114.712     135.614
# x2             0.9324      0.060     15.412      0.000       0.814       1.051
# ==============================================================================
# Omnibus:                        1.445   Durbin-Watson:                   1.981
# Prob(Omnibus):                  0.486   Jarque-Bera (JB):                1.451
# Skew:                          -0.034   Prob(JB):                        0.484
# Kurtosis:                       2.993   Cond. No.                         222.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     17   R-squared (uncentered):                   0.106
# Model:                            OLS   Adj. R-squared (uncentered):              0.105
# Method:                 Least Squares   F-statistic:                              442.4
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   2.47e-182
# Time:                        22:50:24   Log-Likelihood:                          25622.
# No. Observations:                7499   AIC:                                 -5.124e+04
# Df Residuals:                    7497   BIC:                                 -5.123e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           136.4601      5.408     25.232      0.000     125.858     147.062
# x2             1.0484      0.061     17.243      0.000       0.929       1.168
# ==============================================================================
# Omnibus:                        1.349   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.509   Jarque-Bera (JB):                1.357
# Skew:                           0.033   Prob(JB):                        0.507
# Kurtosis:                       2.993   Cond. No.                         232.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     18   R-squared (uncentered):                   0.099
# Model:                            OLS   Adj. R-squared (uncentered):              0.099
# Method:                 Least Squares   F-statistic:                              412.9
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   7.50e-171
# Time:                        22:50:24   Log-Likelihood:                          25689.
# No. Observations:                7499   AIC:                                 -5.137e+04
# Df Residuals:                    7497   BIC:                                 -5.136e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           122.9497      5.101     24.101      0.000     112.950     132.950
# x2             0.9230      0.058     15.850      0.000       0.809       1.037
# ==============================================================================
# Omnibus:                        0.187   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.911   Jarque-Bera (JB):                0.193
# Skew:                           0.012   Prob(JB):                        0.908
# Kurtosis:                       2.995   Cond. No.                         219.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     19   R-squared (uncentered):                   0.094
# Model:                            OLS   Adj. R-squared (uncentered):              0.094
# Method:                 Least Squares   F-statistic:                              389.7
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   1.00e-161
# Time:                        22:50:24   Log-Likelihood:                          25562.
# No. Observations:                7499   AIC:                                 -5.112e+04
# Df Residuals:                    7497   BIC:                                 -5.111e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           116.7012      5.048     23.118      0.000     106.805     126.597
# x2             0.8446      0.058     14.680      0.000       0.732       0.957
# ==============================================================================
# Omnibus:                        2.558   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.278   Jarque-Bera (JB):                2.518
# Skew:                           0.043   Prob(JB):                        0.284
# Kurtosis:                       3.029   Cond. No.                         214.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     20   R-squared (uncentered):                   0.100
# Model:                            OLS   Adj. R-squared (uncentered):              0.099
# Method:                 Least Squares   F-statistic:                              414.7
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   1.57e-171
# Time:                        22:50:24   Log-Likelihood:                          25647.
# No. Observations:                7499   AIC:                                 -5.129e+04
# Df Residuals:                    7497   BIC:                                 -5.128e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           126.0310      5.205     24.212      0.000     115.827     136.235
# x2             0.9578      0.059     16.114      0.000       0.841       1.074
# ==============================================================================
# Omnibus:                        0.132   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.936   Jarque-Bera (JB):                0.115
# Skew:                          -0.008   Prob(JB):                        0.944
# Kurtosis:                       3.010   Cond. No.                         222.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     21   R-squared (uncentered):                   0.100
# Model:                            OLS   Adj. R-squared (uncentered):              0.100
# Method:                 Least Squares   F-statistic:                              417.8
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   9.56e-173
# Time:                        22:50:24   Log-Likelihood:                          25571.
# No. Observations:                7499   AIC:                                 -5.114e+04
# Df Residuals:                    7497   BIC:                                 -5.112e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           128.1658      5.279     24.279      0.000     117.818     138.514
# x2             0.9613      0.060     16.123      0.000       0.844       1.078
# ==============================================================================
# Omnibus:                        2.139   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.343   Jarque-Bera (JB):                2.098
# Skew:                          -0.032   Prob(JB):                        0.350
# Kurtosis:                       3.050   Cond. No.                         224.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     22   R-squared (uncentered):                   0.094
# Model:                            OLS   Adj. R-squared (uncentered):              0.094
# Method:                 Least Squares   F-statistic:                              389.9
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   7.78e-162
# Time:                        22:50:24   Log-Likelihood:                          25530.
# No. Observations:                7499   AIC:                                 -5.106e+04
# Df Residuals:                    7497   BIC:                                 -5.104e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           116.4730      5.160     22.572      0.000     106.358     126.588
# x2             0.8331      0.059     14.064      0.000       0.717       0.949
# ==============================================================================
# Omnibus:                        2.460   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.292   Jarque-Bera (JB):                2.461
# Skew:                          -0.025   Prob(JB):                        0.292
# Kurtosis:                       3.073   Cond. No.                         217.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     23   R-squared (uncentered):                   0.097
# Model:                            OLS   Adj. R-squared (uncentered):              0.097
# Method:                 Least Squares   F-statistic:                              402.0
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   1.48e-166
# Time:                        22:50:24   Log-Likelihood:                          25508.
# No. Observations:                7499   AIC:                                 -5.101e+04
# Df Residuals:                    7497   BIC:                                 -5.100e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
# Model:                            OLS   Adj. R-squared (uncentered):              0.098
# Method:                 Least Squares   F-statistic:                              408.5
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   3.96e-169
# Time:                        22:50:25   Log-Likelihood:                          25580.
# No. Observations:                7499   AIC:                                 -5.116e+04
# Df Residuals:                    7497   BIC:                                 -5.114e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           120.1920      5.065     23.732      0.000     110.264     130.120
# x2             0.8561      0.057     15.093      0.000       0.745       0.967
# ==============================================================================
# Omnibus:                        1.346   Durbin-Watson:                   1.948
# Prob(Omnibus):                  0.510   Jarque-Bera (JB):                1.322
# Skew:                           0.009   Prob(JB):                        0.516
# Kurtosis:                       3.062   Cond. No.                         217.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     93   R-squared (uncentered):                   0.095
# Model:                            OLS   Adj. R-squared (uncentered):              0.095
# Method:                 Least Squares   F-statistic:                              394.3
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   1.50e-163
# Time:                        22:50:25   Log-Likelihood:                          25577.
# No. Observations:                7499   AIC:                                 -5.115e+04
# Df Residuals:                    7497   BIC:                                 -5.114e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           119.9387      5.138     23.344      0.000     109.867     130.010
# x2             0.8908      0.059     15.120      0.000       0.775       1.006
# ==============================================================================
# Omnibus:                        0.593   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.743   Jarque-Bera (JB):                0.551
# Skew:                           0.010   Prob(JB):                        0.759
# Kurtosis:                       3.037   Cond. No.                         217.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     94   R-squared (uncentered):                   0.099
# Model:                            OLS   Adj. R-squared (uncentered):              0.098
# Method:                 Least Squares   F-statistic:                              410.1
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   9.54e-170
# Time:                        22:50:25   Log-Likelihood:                          25577.
# No. Observations:                7499   AIC:                                 -5.115e+04
# Df Residuals:                    7497   BIC:                                 -5.114e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           126.4249      5.243     24.114      0.000     116.147     136.702
# x2             0.9552      0.060     16.035      0.000       0.838       1.072
# ==============================================================================
# Omnibus:                        2.091   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.352   Jarque-Bera (JB):                2.091
# Skew:                          -0.024   Prob(JB):                        0.352
# Kurtosis:                       2.934   Cond. No.                         223.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     95   R-squared (uncentered):                   0.096
# Model:                            OLS   Adj. R-squared (uncentered):              0.096
# Method:                 Least Squares   F-statistic:                              397.8
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   6.65e-165
# Time:                        22:50:25   Log-Likelihood:                          25574.
# No. Observations:                7499   AIC:                                 -5.114e+04
# Df Residuals:                    7497   BIC:                                 -5.113e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           119.5155      5.146     23.225      0.000     109.428     129.603
# x2             0.8739      0.059     14.851      0.000       0.759       0.989
# ==============================================================================
# Omnibus:                        0.836   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.659   Jarque-Bera (JB):                0.868
# Skew:                           0.010   Prob(JB):                        0.648
# Kurtosis:                       2.951   Cond. No.                         218.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     96   R-squared (uncentered):                   0.090
# Model:                            OLS   Adj. R-squared (uncentered):              0.090
# Method:                 Least Squares   F-statistic:                              371.8
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   1.07e-154
# Time:                        22:50:25   Log-Likelihood:                          25450.
# No. Observations:                7499   AIC:                                 -5.090e+04
# Df Residuals:                    7497   BIC:                                 -5.088e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           115.4386      5.141     22.456      0.000     105.361     125.516
# x2             0.8423      0.059     14.228      0.000       0.726       0.958
# ==============================================================================
# Omnibus:                        1.021   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.600   Jarque-Bera (JB):                1.056
# Skew:                           0.019   Prob(JB):                        0.590
# Kurtosis:                       2.957   Cond. No.                         214.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     97   R-squared (uncentered):                   0.092
# Model:                            OLS   Adj. R-squared (uncentered):              0.092
# Method:                 Least Squares   F-statistic:                              380.1
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   5.69e-158
# Time:                        22:50:25   Log-Likelihood:                          25501.
# No. Observations:                7499   AIC:                                 -5.100e+04
# Df Residuals:                    7497   BIC:                                 -5.098e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           116.5507      5.156     22.605      0.000     106.444     126.658
# x2             0.8525      0.059     14.336      0.000       0.736       0.969
# ==============================================================================
# Omnibus:                        0.331   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.847   Jarque-Bera (JB):                0.294
# Skew:                          -0.007   Prob(JB):                        0.863
# Kurtosis:                       3.028   Cond. No.                         215.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     98   R-squared (uncentered):                   0.095
# Model:                            OLS   Adj. R-squared (uncentered):              0.095
# Method:                 Least Squares   F-statistic:                              393.7
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   2.52e-163
# Time:                        22:50:25   Log-Likelihood:                          25547.
# No. Observations:                7499   AIC:                                 -5.109e+04
# Df Residuals:                    7497   BIC:                                 -5.108e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           118.2742      5.138     23.018      0.000     108.201     128.347
# x2             0.8565      0.059     14.589      0.000       0.741       0.972
# ==============================================================================
# Omnibus:                        1.139   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.566   Jarque-Bera (JB):                1.174
# Skew:                           0.022   Prob(JB):                        0.556
# Kurtosis:                       2.957   Cond. No.                         217.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     99   R-squared (uncentered):                   0.092
# Model:                            OLS   Adj. R-squared (uncentered):              0.092
# Method:                 Least Squares   F-statistic:                              381.9
# Date:                Mon, 31 Oct 2022   Prob (F-statistic):                   1.19e-158
# Time:                        22:50:25   Log-Likelihood:                          25467.
# No. Observations:                7499   AIC:                                 -5.093e+04
# Df Residuals:                    7497   BIC:                                 -5.092e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           119.3916      5.223     22.860      0.000     109.154     129.629
# x2             0.8849      0.060     14.737      0.000       0.767       1.003
# ==============================================================================
# Omnibus:                        1.678   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.432   Jarque-Bera (JB):                1.713
# Skew:                          -0.033   Prob(JB):                        0.425
# Kurtosis:                       2.966   Cond. No.                         217.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### 2. ML

# %%
a,b,sigma
# Out:
# (0.9100101993332262, 135.09418157986403, 0.39990734424709956)

# %% [markdown]
# #### 3. Solvers

# %%
calibrate_dataMLE(df, method = "Nelder-Mead")
# Out:
# 100%|██████████| 100/100 [00:22<00:00,  4.42it/s]
# No of iter:  65.02
# (0.9100101993332262, 135.09418157986403, 0.39990734424709956)

# %%
negloglik((0.9100101993332262, 135.09418157986403, 0.39990734424709956),T,df)[1:].mean()
# Out:
# c:\Users\vigne\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:402: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# -12080.107425385959

# %%
calibrate_dataMLE(df, method = "BFGS")
# Out:
# 100%|██████████| 100/100 [00:40<00:00,  2.47it/s]
# No of iter:  2.58
# (0.9098549658090235, 135.09396824764636, 0.39990949958243)

# %%
negloglik((0.9098549658090235, 135.09396824764636, 0.39990949958243),T,df)[1:].mean()
# Out:
# c:\Users\vigne\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:402: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# -12080.212661632959

# %%
calibrate_dataMLE(df, method = "L-BFGS-B")
# Out:
# 100%|██████████| 100/100 [00:06<00:00, 14.73it/s]
# No of iter:  0.99
# (0.9069713800379191, 135.06920819671774, 0.3425973787638769)

# %%
negloglik((0.9069713800379191, 135.06920819671774, 0.3425973787638769),T,df)[1:].mean()
# Out:
# c:\Users\vigne\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:402: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# -13096.108099293984
